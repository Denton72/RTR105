# %%
import sys
sys.path.append('/usr/local/anaconda3/lib/python3.6/site-packages')
from numpy import * # Importē skaitlisko metožu bibliotēkas funkcijas
from matplotlib import pyplot as plt
x = linspace(0, 7, 70)  # Trešais arguments ir ģenerējamo elementu skaits
y = cos(x)
y2 = arcsin(x)
y3 = sin(-x)
y4 = sin(x)
y5 = cos(sqrt(x))
y6 = arcsin(-x)

print('linspace values:')
print(x)
print('cos values:')
print(y)
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)', color = "#990000")
plt.title('Funkcija $cos(x), arcsin(x), sin(-x) sin(x)$' , color = "#999900")
plt.plot(x, y, color = "#990055")
plt.plot(x,y2, color = "#000099")
plt.plot(x,y3, color = "#009900")
plt.plot(x,y4, color = "#009000")
plt.plot(x,y6, color = "#000099")
plt.plot(x,y5, color = "#990055")
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in arcsin
#   import sys
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in arcsin
#   # This is added back by InteractiveShellApp.init_path()
# linspace values:
# [0.         0.10144928 0.20289855 0.30434783 0.4057971  0.50724638
#  0.60869565 0.71014493 0.8115942  0.91304348 1.01449275 1.11594203
#  1.2173913  1.31884058 1.42028986 1.52173913 1.62318841 1.72463768
#  1.82608696 1.92753623 2.02898551 2.13043478 2.23188406 2.33333333
#  2.43478261 2.53623188 2.63768116 2.73913043 2.84057971 2.94202899
#  3.04347826 3.14492754 3.24637681 3.34782609 3.44927536 3.55072464
#  3.65217391 3.75362319 3.85507246 3.95652174 4.05797101 4.15942029
#  4.26086957 4.36231884 4.46376812 4.56521739 4.66666667 4.76811594
#  4.86956522 4.97101449 5.07246377 5.17391304 5.27536232 5.37681159
#  5.47826087 5.57971014 5.68115942 5.7826087  5.88405797 5.98550725
#  6.08695652 6.1884058  6.28985507 6.39130435 6.49275362 6.5942029
#  6.69565217 6.79710145 6.89855072 7.        ]
# cos values:
# [ 1.          0.99485843  0.97948661  0.95404259  0.91878803  0.87408545
#   0.82039454  0.7582674   0.6883429   0.61134007  0.52805076  0.43933143
#   0.3460944   0.24929843  0.1499389   0.04903752 -0.05236811 -0.15323524
#  -0.25252663 -0.34922125 -0.44232479 -0.53087984 -0.61397579 -0.69075814
#  -0.76043733 -0.82229685 -0.87570058 -0.92009937 -0.95503665 -0.98015317
#  -0.99519064 -0.99999444 -0.99451516 -0.97880915 -0.95303792 -0.91746648
#  -0.8724606  -0.8184831  -0.75608903 -0.68592    -0.60869756 -0.5252158
#  -0.43633318 -0.34296369 -0.24606746 -0.14664089 -0.04570638  0.05569812
#   0.15652988  0.25575202  0.35234423  0.44531323  0.53370302  0.61660468
#   0.6931657   0.76259881  0.82419002  0.87730597  0.92140047  0.95602009
#   0.98080883  0.99551178  0.99997776  0.99416083  0.97812081  0.95202265
#   0.91613472  0.87082605  0.81656256  0.75390225]
